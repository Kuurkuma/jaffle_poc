# %% [markdown]
# # dlt assessment - Jaffle API ingestion

# %% [markdown]
# 1. Describe how you would use dlt in a previous job or project. If you don’t have a real example, pick a realistic one (e.g., analytics platform, marketing data, finance reporting, product telemetry). Aim for 5–10 sentences, focused on clarity and trade-offs.
#
# 2. Build a dlt pipeline, using our Jaffle Shop API as a source and DuckDB as a destination.
# Use the API spec for this API and the “https://jaffle-shop.dlthub.com/api/v1” as an API base URL
# Make sure you use some more advanced dlt functionality like the merge write disposition and incremental loading.
#
# 3. Assume this pipeline is the starting point for a real engagement with a client. Describe how you would take it to production.
# List the key questions you’d ask before recommending a setup.
# Highlight the aspects the client needs to pay attention to. You don’t need to go super deep, highlight one or two aspects you would ask the client to consider when running this pipeline in production.
# What would you recommend for the best practices for dlt code & deployment. You can talk about env & configuraiton, testing and validation, CI/CD, orchestration & runtime.

# %% [markdown]
# # 1. dlt use cases
#
# 1. Unified Ads Performance Dashboard (Facebook & Google)
#
# **Problem**
#
# A marketing company using direct connectors ( Supermetrics) for Facebook and Google Ads faced expensive licensing fees and slow dashboards.
# They lacked a centralized database.
#
# **Objective**
#
# Replace the slow connectors with a dlt-based ELT pipeline that ingests raw data directly into BigQuery. This aimed to unify ad spend metrics into a single, high-performance SQL view for fast and accurate reporting in Looker Studio.
#
# **Limits**
#
# No data people in the team to follow up or create the SQL requests necessary for the dashboard. Company not data mature to consider the need of a data pipeline.
#
# 2. Lightweight API Ingestion for a Solo Analyst
#
# **Problem**
#
# A solo data analyst needed to centralize data from five distinct APIs into Snowflake but faced budget constraints that ruled out managed SaaS solutions like Airbyte Cloud. His attempt to self-host Airbyte on Kubernetes (GKE) proved operationally overwhelming and too complex for a one-person team to maintain.
#
# **Objective**
#
# The goal was to replace heavy infrastructure with a lightweight dlt-based pipeline that runs on simple CLoud Function. This approach aimed to bypass the complexity of managing a self-hosted platform.
#
# **Limits**
#
# The data Analyst were not very comfortable to manage a python ingestion pipeline by himself.

# %% [markdown]
# # 2. Build a dlt pipeline for Jaffle API

# %% [markdown]
# ### Gettings source informations

# %%
# first we need to get all endpoints infos
# !curl https://jaffle-shop.dlthub.com/docs
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     <link type="text/css" rel="stylesheet" href="https://cdn.jsdelivr.net/npm/swagger-ui-dist@5/swagger-ui.css">
#     <link rel="shortcut icon" href="https://fastapi.tiangolo.com/img/favicon.png">
#     <title>dltHub Jaffle Shop API - Swagger UI</title>
#     </head>
#     <body>
#     <div id="swagger-ui">
#     </div>
#     <script src="https://cdn.jsdelivr.net/npm/swagger-ui-dist@5/swagger-ui-bundle.js"></script>
#     <!-- `SwaggerUIBundle` is now available on the page -->
#     <script>
#     const ui = SwaggerUIBundle({
#         url: '/openapi.json',
#     "dom_id": "#swagger-ui",
# "layout": "BaseLayout",
# "deepLinking": true,
# "showExtensions": true,
# "showCommonExtensions": true,
# oauth2RedirectUrl: window.location.origin + '/docs/oauth2-redirect',
#     presets: [
#         SwaggerUIBundle.presets.apis,
#         SwaggerUIBundle.SwaggerUIStandalonePreset
#         ],
#     })
#     </script>
#     </body>
#     </html>

# %%
import dlt
from dlt.sources.helpers import requests
import duckdb
import json

# the url is '/openapi.json', so lets create a local json to have all infos available.
api_doc_url = "https://jaffle-shop.dlthub.com/openapi.json"

api_doc_json = requests.get(api_doc_url).json()
#print(api_doc_json)

# %%
# by storing the entier json doc, we will have a more precise overview of endpoints and parameters. 
# We could potentially feed an LLM to write a markdowon human friendly documentation.

with open('jaffle_api_doc.json', 'w') as doc:
    json.dump(api_doc_json, doc)

# %% [markdown]
# ### Create the source ressources

# %%
# using the .config file to store environment variables
base_url = dlt.config["runtime.BASE_URL"]
print(base_url)
# Out:
# https://jaffle-shop.dlthub.com/api/v1

# %% [markdown]
# ### Creation Jaffle APi source by creating the ressources

# %%
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.paginators import HeaderLinkPaginator

# list of existing endpoints for potential dynamic ressources creation
endpoints = ["customers","orders","items","products","supplies","stores", "row_counts" ]
page_size = 100 # page size is the same across the API

@dlt.source
def get_jaffle_api(base_url: str = base_url, page_size: int = page_size):
    # we initialise the client once because they share the same params
    client = RESTClient(
        base_url=base_url,
        paginator=HeaderLinkPaginator(links_next_key="next"), # based on api doc, we use the header link
    )

    @dlt.resource(name='customers', write_disposition='merge', primary_key='id') # endpoint gives an id and a name. 
    def get_customers():
        """Retrieves customers from the Jaffle Shop API"""
        for page in client.paginate('customers',params={"page_size": page_size}):
            yield page
    
    @dlt.resource(name='orders', write_disposition='append') # doesnt have any 'updated_at' column so append is the right way to do. 
    def get_orders(page_size: int = page_size):
        """Retrieves orders from the Jaffle Shop API."""

        for page in client.paginate('orders',params={"page_size": page_size}):
            yield page


    @dlt.resource(name='items', write_disposition='append') #items associated to an order. many to many relation. we need to append here
    def get_items(page_size: int = page_size):
        """Retrieves items from the Jaffle Shop API."""

        for page in client.paginate('items',params={"page_size": page_size}):
            yield page

    @dlt.resource(name='products', write_disposition='merge', primary_key='sku') #products database, probably not updated often but important to catch those changes. we changed the PK to sku
    def get_products(page_size: int = page_size):
        """Retrieves products from the Jaffle Shop API."""

        for page in client.paginate('products',params={"page_size": page_size}):
            yield page


    @dlt.resource(name='supplies', write_disposition='merge', primary_key='id')
    def get_supplies(page_size: int = page_size):
        """Retrieves supplies from the Jaffle Shop API."""

        for page in client.paginate('supplies',params={"page_size": page_size}):
            yield page


    @dlt.resource(name='stores', write_disposition='merge', primary_key='id' )
    def get_stores(page_size: int = page_size):
        """Retrieves stores from the Jaffle Shop API."""
        
        for page in client.paginate('stores',params={"page_size": page_size}):
            yield page

    @dlt.resource # optional. useful for comparing data source rows and ingested rows
    def get_row_counts(name='row_counts'):
        """Rerieves row counts from the Jaffle Shop API."""
        
        for page in client.paginate('row-counts',params={"page_size": page_size}):
            yield page


    return (get_customers, get_orders, get_items, get_products, get_supplies, get_stores, get_row_counts)

# %% [markdown]
# ### Pipeline run

# %%
pipeline = dlt.pipeline(
    pipeline_name="jaffle_pipeline",
    destination="duckdb",
    dataset_name="raw_data",
    progress='log',
    dev_mode=True, # allow us to debug while building this PoC. to remove before going to production
    #refresh=True
)

load_info = pipeline.run(get_jaffle_api())
print(load_info)
# Out:
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/7 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 139.67 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/7 (0.0%) | Time: 0.12s | Rate: 0.00/s
# customers: 100  | Time: 0.00s | Rate: 59918628.57/s
# Memory usage: 146.84 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/7 (0.0%) | Time: 0.14s | Rate: 0.00/s
# customers: 100  | Time: 0.02s | Rate: 4278.64/s
# orders: 100  | Time: 0.00s | Rate: 46603377.78/s
# Memory usage: 147.17 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/7 (0.0%) | Time: 0.16s | Rate: 0.00/s
# customers: 100  | Time: 0.05s | Rate: 2169.11/s
# orders: 100  | Time: 0.02s | Rate: 4399.08/s
# items: 100  | Time: 0.00s | Rate: 52428800.00/s
# Memory usage: 147.41 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/7 (0.0%) | Time: 0.19s | Rate: 0.00/s
# customers: 100  | Time: 0.07s | Rate: 1405.32/s
# orders: 100  | Time: 0.05s | Rate: 2092.57/s
# items: 100  | Time: 0.03s | Rate: 3990.74/s
# products: 10  | Time: 0.00s | Rate: 4660337.78/s
# Memory usage: 148.19 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/7 (0.0%) | Time: 0.21s | Rate: 0.00/s
# customers: 100  | Time: 0.09s | Rate: 1066.03/s
# orders: 100  | Time: 0.07s | Rate: 1419.73/s
# items: 100  | Time: 0.05s | Rate: 2096.18/s
# products: 10  | Time: 0.02s | Rate: 441.50/s
# supplies: 65  | Time: 0.00s | Rate: 17039360.00/s
# Memory usage: 148.36 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/7 (0.0%) | Time: 0.23s | Rate: 0.00/s
# customers: 100  | Time: 0.12s | Rate: 862.20/s
# orders: 100  | Time: 0.09s | Rate: 1079.77/s
# items: 100  | Time: 0.07s | Rate: 1430.99/s
# products: 10  | Time: 0.04s | Rate: 223.08/s
# supplies: 65  | Time: 0.02s | Rate: 2930.59/s
# stores: 6  | Time: 0.00s | Rate: 2097152.00/s
# Memory usage: 148.62 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/7 (0.0%) | Time: 0.26s | Rate: 0.00/s
# customers: 100  | Time: 0.14s | Rate: 712.72/s
# orders: 100  | Time: 0.12s | Rate: 855.15/s
# items: 100  | Time: 0.09s | Rate: 1061.48/s
# products: 10  | Time: 0.07s | Rate: 144.61/s
# supplies: 65  | Time: 0.05s | Rate: 1397.67/s
# stores: 6  | Time: 0.02s | Rate: 246.62/s
# get_row_counts: 6  | Time: 0.00s | Rate: 1935832.62/s
# Memory usage: 148.88 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 1.27s | Rate: 3.95/s
# customers: 935  | Time: 1.15s | Rate: 812.76/s
# orders: 1900  | Time: 1.13s | Rate: 1685.84/s
# items: 1800  | Time: 1.10s | Rate: 1629.98/s
# products: 10  | Time: 1.08s | Rate: 9.27/s
# supplies: 65  | Time: 1.06s | Rate: 61.52/s
# stores: 6  | Time: 1.03s | Rate: 5.80/s
# get_row_counts: 6  | Time: 1.01s | Rate: 5.94/s
# Memory usage: 152.09 MB (69.60%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 2.28s | Rate: 2.19/s
# customers: 935  | Time: 2.17s | Rate: 431.53/s
# orders: 4100  | Time: 2.14s | Rate: 1912.91/s
# items: 4000  | Time: 2.12s | Rate: 1886.26/s
# products: 10  | Time: 2.10s | Rate: 4.77/s
# supplies: 65  | Time: 2.07s | Rate: 31.36/s
# stores: 6  | Time: 2.05s | Rate: 2.93/s
# get_row_counts: 6  | Time: 2.03s | Rate: 2.96/s
# Memory usage: 154.48 MB (69.50%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 3.30s | Rate: 1.52/s
# customers: 935  | Time: 3.18s | Rate: 294.03/s
# orders: 6300  | Time: 3.16s | Rate: 1995.82/s
# items: 6200  | Time: 3.13s | Rate: 1978.39/s
# products: 10  | Time: 3.11s | Rate: 3.22/s
# supplies: 65  | Time: 3.09s | Rate: 21.06/s
# stores: 6  | Time: 3.06s | Rate: 1.96/s
# get_row_counts: 6  | Time: 3.04s | Rate: 1.97/s
# Memory usage: 157.78 MB (69.20%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 4.30s | Rate: 1.16/s
# customers: 935  | Time: 4.18s | Rate: 223.59/s
# orders: 8400  | Time: 4.16s | Rate: 2020.03/s
# items: 8400  | Time: 4.14s | Rate: 2031.13/s
# products: 10  | Time: 4.11s | Rate: 2.43/s
# supplies: 65  | Time: 4.09s | Rate: 15.90/s
# stores: 6  | Time: 4.07s | Rate: 1.48/s
# get_row_counts: 6  | Time: 4.04s | Rate: 1.48/s
# Memory usage: 207.52 MB (69.20%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 5.31s | Rate: 0.94/s
# customers: 935  | Time: 5.19s | Rate: 180.14/s
# orders: 10600  | Time: 5.17s | Rate: 2051.41/s
# items: 10600  | Time: 5.14s | Rate: 2060.47/s
# products: 10  | Time: 5.12s | Rate: 1.95/s
# supplies: 65  | Time: 5.10s | Rate: 12.75/s
# stores: 6  | Time: 5.07s | Rate: 1.18/s
# get_row_counts: 6  | Time: 5.05s | Rate: 1.19/s
# Memory usage: 210.88 MB (69.20%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 6.32s | Rate: 0.79/s
# customers: 935  | Time: 6.20s | Rate: 150.80/s
# orders: 12900  | Time: 6.18s | Rate: 2088.36/s
# items: 12900  | Time: 6.15s | Rate: 2096.07/s
# products: 10  | Time: 6.13s | Rate: 1.63/s
# supplies: 65  | Time: 6.11s | Rate: 10.64/s
# stores: 6  | Time: 6.08s | Rate: 0.99/s
# get_row_counts: 6  | Time: 6.06s | Rate: 0.99/s
# Memory usage: 211.02 MB (68.90%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 7.33s | Rate: 0.68/s
# customers: 935  | Time: 7.22s | Rate: 129.53/s
# orders: 15200  | Time: 7.19s | Rate: 2112.63/s
# items: 15100  | Time: 7.17s | Rate: 2105.39/s
# products: 10  | Time: 7.15s | Rate: 1.40/s
# supplies: 65  | Time: 7.12s | Rate: 9.12/s
# stores: 6  | Time: 7.10s | Rate: 0.84/s
# get_row_counts: 6  | Time: 7.08s | Rate: 0.85/s
# Memory usage: 212.86 MB (68.90%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 8.35s | Rate: 0.60/s
# customers: 935  | Time: 8.23s | Rate: 113.55/s
# orders: 17500  | Time: 8.21s | Rate: 2131.34/s
# items: 17400  | Time: 8.19s | Rate: 2125.05/s
# products: 10  | Time: 8.16s | Rate: 1.23/s
# supplies: 65  | Time: 8.14s | Rate: 7.98/s
# stores: 6  | Time: 8.12s | Rate: 0.74/s
# get_row_counts: 6  | Time: 8.09s | Rate: 0.74/s
# Memory usage: 212.91 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 9.36s | Rate: 0.53/s
# customers: 935  | Time: 9.25s | Rate: 101.11/s
# orders: 19800  | Time: 9.22s | Rate: 2146.51/s
# items: 19800  | Time: 9.20s | Rate: 2151.81/s
# products: 10  | Time: 9.18s | Rate: 1.09/s
# supplies: 65  | Time: 9.15s | Rate: 7.10/s
# stores: 6  | Time: 9.13s | Rate: 0.66/s
# get_row_counts: 6  | Time: 9.11s | Rate: 0.66/s
# Memory usage: 213.12 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 10.38s | Rate: 0.48/s
# customers: 935  | Time: 10.27s | Rate: 91.09/s
# orders: 21900  | Time: 10.24s | Rate: 2138.32/s
# items: 21800  | Time: 10.22s | Rate: 2133.29/s
# products: 10  | Time: 10.19s | Rate: 0.98/s
# supplies: 65  | Time: 10.17s | Rate: 6.39/s
# stores: 6  | Time: 10.15s | Rate: 0.59/s
# get_row_counts: 6  | Time: 10.12s | Rate: 0.59/s
# Memory usage: 215.73 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 11.40s | Rate: 0.44/s
# customers: 935  | Time: 11.28s | Rate: 82.87/s
# orders: 24300  | Time: 11.26s | Rate: 2158.18/s
# items: 24200  | Time: 11.24s | Rate: 2153.64/s
# products: 10  | Time: 11.21s | Rate: 0.89/s
# supplies: 65  | Time: 11.19s | Rate: 5.81/s
# stores: 6  | Time: 11.17s | Rate: 0.54/s
# get_row_counts: 6  | Time: 11.14s | Rate: 0.54/s
# Memory usage: 215.77 MB (69.20%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 12.40s | Rate: 0.40/s
# customers: 935  | Time: 12.28s | Rate: 76.11/s
# orders: 26400  | Time: 12.26s | Rate: 2153.22/s
# items: 26300  | Time: 12.24s | Rate: 2149.04/s
# products: 10  | Time: 12.21s | Rate: 0.82/s
# supplies: 65  | Time: 12.19s | Rate: 5.33/s
# stores: 6  | Time: 12.17s | Rate: 0.49/s
# get_row_counts: 6  | Time: 12.14s | Rate: 0.49/s
# Memory usage: 216.09 MB (69.10%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 13.40s | Rate: 0.37/s
# customers: 935  | Time: 13.29s | Rate: 70.36/s
# orders: 28500  | Time: 13.27s | Rate: 2148.45/s
# items: 28500  | Time: 13.24s | Rate: 2152.13/s
# products: 10  | Time: 13.22s | Rate: 0.76/s
# supplies: 65  | Time: 13.19s | Rate: 4.93/s
# stores: 6  | Time: 13.17s | Rate: 0.46/s
# get_row_counts: 6  | Time: 13.15s | Rate: 0.46/s
# Memory usage: 216.09 MB (68.90%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 14.42s | Rate: 0.35/s
# customers: 935  | Time: 14.30s | Rate: 65.38/s
# orders: 30600  | Time: 14.28s | Rate: 2143.22/s
# items: 30500  | Time: 14.25s | Rate: 2139.62/s
# products: 10  | Time: 14.23s | Rate: 0.70/s
# supplies: 65  | Time: 14.21s | Rate: 4.58/s
# stores: 6  | Time: 14.18s | Rate: 0.42/s
# get_row_counts: 6  | Time: 14.16s | Rate: 0.42/s
# Memory usage: 218.47 MB (68.90%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 15.43s | Rate: 0.32/s
# customers: 935  | Time: 15.31s | Rate: 61.06/s
# orders: 32900  | Time: 15.29s | Rate: 2151.97/s
# items: 32800  | Time: 15.27s | Rate: 2148.62/s
# products: 10  | Time: 15.24s | Rate: 0.66/s
# supplies: 65  | Time: 15.22s | Rate: 4.27/s
# stores: 6  | Time: 15.20s | Rate: 0.39/s
# get_row_counts: 6  | Time: 15.17s | Rate: 0.40/s
# Memory usage: 218.55 MB (69.00%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 16.47s | Rate: 0.30/s
# customers: 935  | Time: 16.35s | Rate: 57.19/s
# orders: 35000  | Time: 16.33s | Rate: 2143.72/s
# items: 35000  | Time: 16.30s | Rate: 2146.71/s
# products: 10  | Time: 16.28s | Rate: 0.61/s
# supplies: 65  | Time: 16.26s | Rate: 4.00/s
# stores: 6  | Time: 16.23s | Rate: 0.37/s
# get_row_counts: 6  | Time: 16.21s | Rate: 0.37/s
# Memory usage: 219.67 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 17.48s | Rate: 0.29/s
# customers: 935  | Time: 17.36s | Rate: 53.85/s
# orders: 37300  | Time: 17.34s | Rate: 2151.16/s
# items: 37200  | Time: 17.32s | Rate: 2148.21/s
# products: 10  | Time: 17.29s | Rate: 0.58/s
# supplies: 65  | Time: 17.27s | Rate: 3.76/s
# stores: 6  | Time: 17.25s | Rate: 0.35/s
# get_row_counts: 6  | Time: 17.22s | Rate: 0.35/s
# Memory usage: 219.83 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 18.49s | Rate: 0.27/s
# customers: 935  | Time: 18.37s | Rate: 50.90/s
# orders: 39600  | Time: 18.35s | Rate: 2158.34/s
# items: 39600  | Time: 18.32s | Rate: 2161.02/s
# products: 10  | Time: 18.30s | Rate: 0.55/s
# supplies: 65  | Time: 18.28s | Rate: 3.56/s
# stores: 6  | Time: 18.25s | Rate: 0.33/s
# get_row_counts: 6  | Time: 18.23s | Rate: 0.33/s
# Memory usage: 219.86 MB (69.70%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 19.50s | Rate: 0.26/s
# customers: 935  | Time: 19.39s | Rate: 48.22/s
# orders: 41800  | Time: 19.37s | Rate: 2158.49/s
# items: 41700  | Time: 19.34s | Rate: 2155.86/s
# products: 10  | Time: 19.32s | Rate: 0.52/s
# supplies: 65  | Time: 19.29s | Rate: 3.37/s
# stores: 6  | Time: 19.27s | Rate: 0.31/s
# get_row_counts: 6  | Time: 19.25s | Rate: 0.31/s
# Memory usage: 222.12 MB (69.50%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 20.52s | Rate: 0.24/s
# customers: 935  | Time: 20.40s | Rate: 45.82/s
# orders: 43900  | Time: 20.38s | Rate: 2154.01/s
# items: 43900  | Time: 20.36s | Rate: 2156.42/s
# products: 10  | Time: 20.33s | Rate: 0.49/s
# supplies: 65  | Time: 20.31s | Rate: 3.20/s
# stores: 6  | Time: 20.29s | Rate: 0.30/s
# get_row_counts: 6  | Time: 20.26s | Rate: 0.30/s
# Memory usage: 222.20 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 21.53s | Rate: 0.23/s
# customers: 935  | Time: 21.41s | Rate: 43.66/s
# orders: 45900  | Time: 21.39s | Rate: 2145.73/s
# items: 45900  | Time: 21.37s | Rate: 2148.02/s
# products: 10  | Time: 21.34s | Rate: 0.47/s
# supplies: 65  | Time: 21.32s | Rate: 3.05/s
# stores: 6  | Time: 21.30s | Rate: 0.28/s
# get_row_counts: 6  | Time: 21.27s | Rate: 0.28/s
# Memory usage: 223.19 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 22.55s | Rate: 0.22/s
# customers: 935  | Time: 22.43s | Rate: 41.68/s
# orders: 48100  | Time: 22.41s | Rate: 2146.37/s
# items: 48100  | Time: 22.39s | Rate: 2148.55/s
# products: 10  | Time: 22.36s | Rate: 0.45/s
# supplies: 65  | Time: 22.34s | Rate: 2.91/s
# stores: 6  | Time: 22.32s | Rate: 0.27/s
# get_row_counts: 6  | Time: 22.29s | Rate: 0.27/s
# Memory usage: 223.25 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 23.55s | Rate: 0.21/s
# customers: 935  | Time: 23.44s | Rate: 39.89/s
# orders: 50100  | Time: 23.42s | Rate: 2139.57/s
# items: 50000  | Time: 23.39s | Rate: 2137.37/s
# products: 10  | Time: 23.37s | Rate: 0.43/s
# supplies: 65  | Time: 23.35s | Rate: 2.78/s
# stores: 6  | Time: 23.32s | Rate: 0.26/s
# get_row_counts: 6  | Time: 23.30s | Rate: 0.26/s
# Memory usage: 225.48 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 24.58s | Rate: 0.20/s
# customers: 935  | Time: 24.46s | Rate: 38.23/s
# orders: 52300  | Time: 24.44s | Rate: 2140.26/s
# items: 52300  | Time: 24.41s | Rate: 2142.25/s
# products: 10  | Time: 24.39s | Rate: 0.41/s
# supplies: 65  | Time: 24.37s | Rate: 2.67/s
# stores: 6  | Time: 24.34s | Rate: 0.25/s
# get_row_counts: 6  | Time: 24.32s | Rate: 0.25/s
# Memory usage: 225.62 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 25.58s | Rate: 0.20/s
# customers: 935  | Time: 25.46s | Rate: 36.72/s
# orders: 54600  | Time: 25.44s | Rate: 2146.13/s
# items: 54600  | Time: 25.42s | Rate: 2148.05/s
# products: 10  | Time: 25.39s | Rate: 0.39/s
# supplies: 65  | Time: 25.37s | Rate: 2.56/s
# stores: 6  | Time: 25.35s | Rate: 0.24/s
# get_row_counts: 6  | Time: 25.32s | Rate: 0.24/s
# Memory usage: 225.62 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 26.58s | Rate: 0.19/s
# customers: 935  | Time: 26.47s | Rate: 35.33/s
# orders: 56800  | Time: 26.44s | Rate: 2147.99/s
# items: 56700  | Time: 26.42s | Rate: 2146.05/s
# products: 10  | Time: 26.40s | Rate: 0.38/s
# supplies: 65  | Time: 26.37s | Rate: 2.46/s
# stores: 6  | Time: 26.35s | Rate: 0.23/s
# get_row_counts: 6  | Time: 26.33s | Rate: 0.23/s
# Memory usage: 227.69 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 27.60s | Rate: 0.18/s
# customers: 935  | Time: 27.48s | Rate: 34.03/s
# orders: 59000  | Time: 27.46s | Rate: 2148.86/s
# items: 58900  | Time: 27.43s | Rate: 2147.00/s
# products: 10  | Time: 27.41s | Rate: 0.36/s
# supplies: 65  | Time: 27.39s | Rate: 2.37/s
# stores: 6  | Time: 27.36s | Rate: 0.22/s
# get_row_counts: 6  | Time: 27.34s | Rate: 0.22/s
# Memory usage: 227.69 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 5/7 (71.4%) | Time: 28.61s | Rate: 0.17/s
# customers: 935  | Time: 28.49s | Rate: 32.82/s
# orders: 61100  | Time: 28.47s | Rate: 2146.15/s
# items: 61000  | Time: 28.45s | Rate: 2144.34/s
# products: 10  | Time: 28.42s | Rate: 0.35/s
# supplies: 65  | Time: 28.40s | Rate: 2.29/s
# stores: 6  | Time: 28.38s | Rate: 0.21/s
# get_row_counts: 6  | Time: 28.35s | Rate: 0.21/s
# Memory usage: 227.70 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 6/7 (85.7%) | Time: 29.62s | Rate: 0.20/s
# customers: 935  | Time: 29.50s | Rate: 31.69/s
# orders: 61948  | Time: 29.48s | Rate: 2101.38/s
# items: 64600  | Time: 29.46s | Rate: 2193.03/s
# products: 10  | Time: 29.43s | Rate: 0.34/s
# supplies: 65  | Time: 29.41s | Rate: 2.21/s
# stores: 6  | Time: 29.39s | Rate: 0.20/s
# get_row_counts: 6  | Time: 29.36s | Rate: 0.20/s
# Memory usage: 227.70 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 6/7 (85.7%) | Time: 30.63s | Rate: 0.20/s
# customers: 935  | Time: 30.52s | Rate: 30.64/s
# orders: 61948  | Time: 30.49s | Rate: 2031.58/s
# items: 69100  | Time: 30.47s | Rate: 2267.82/s
# products: 10  | Time: 30.44s | Rate: 0.33/s
# supplies: 65  | Time: 30.42s | Rate: 2.14/s
# stores: 6  | Time: 30.40s | Rate: 0.20/s
# get_row_counts: 6  | Time: 30.38s | Rate: 0.20/s
# Memory usage: 227.70 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 6/7 (85.7%) | Time: 31.63s | Rate: 0.19/s
# customers: 935  | Time: 31.52s | Rate: 29.67/s
# orders: 61948  | Time: 31.49s | Rate: 1967.03/s
# items: 73600  | Time: 31.47s | Rate: 2338.70/s
# products: 10  | Time: 31.45s | Rate: 0.32/s
# supplies: 65  | Time: 31.42s | Rate: 2.07/s
# stores: 6  | Time: 31.40s | Rate: 0.19/s
# get_row_counts: 6  | Time: 31.38s | Rate: 0.19/s
# Memory usage: 227.77 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 6/7 (85.7%) | Time: 32.65s | Rate: 0.18/s
# customers: 935  | Time: 32.53s | Rate: 28.74/s
# orders: 61948  | Time: 32.51s | Rate: 1905.52/s
# items: 77900  | Time: 32.49s | Rate: 2397.87/s
# products: 10  | Time: 32.46s | Rate: 0.31/s
# supplies: 65  | Time: 32.44s | Rate: 2.00/s
# stores: 6  | Time: 32.42s | Rate: 0.19/s
# get_row_counts: 6  | Time: 32.39s | Rate: 0.19/s
# Memory usage: 227.77 MB (69.40%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 6/7 (85.7%) | Time: 33.67s | Rate: 0.18/s
# customers: 935  | Time: 33.55s | Rate: 27.87/s
# orders: 61948  | Time: 33.53s | Rate: 1847.61/s
# items: 82600  | Time: 33.51s | Rate: 2465.23/s
# products: 10  | Time: 33.48s | Rate: 0.30/s
# supplies: 65  | Time: 33.46s | Rate: 1.94/s
# stores: 6  | Time: 33.44s | Rate: 0.18/s
# get_row_counts: 6  | Time: 33.41s | Rate: 0.18/s
# Memory usage: 227.77 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 6/7 (85.7%) | Time: 34.67s | Rate: 0.17/s
# customers: 935  | Time: 34.55s | Rate: 27.06/s
# orders: 61948  | Time: 34.53s | Rate: 1794.06/s
# items: 87200  | Time: 34.51s | Rate: 2527.05/s
# products: 10  | Time: 34.48s | Rate: 0.29/s
# supplies: 65  | Time: 34.46s | Rate: 1.89/s
# stores: 6  | Time: 34.44s | Rate: 0.17/s
# get_row_counts: 6  | Time: 34.41s | Rate: 0.17/s
# Memory usage: 227.77 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 7/7 (100.0%) | Time: 35.54s | Rate: 0.20/s
# customers: 935  | Time: 35.43s | Rate: 26.39/s
# orders: 61948  | Time: 35.40s | Rate: 1749.84/s
# items: 90900  | Time: 35.38s | Rate: 2569.29/s
# products: 10  | Time: 35.35s | Rate: 0.28/s
# supplies: 65  | Time: 35.33s | Rate: 1.84/s
# stores: 6  | Time: 35.31s | Rate: 0.17/s
# get_row_counts: 6  | Time: 35.29s | Rate: 0.17/s
# Memory usage: 227.94 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 227.94 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 0/1 (0.0%) | Time: 0.00s | Rate: 0.00/s
# _dlt_pipeline_state: 1  | Time: 0.00s | Rate: 524288.00/s
# Memory usage: 227.94 MB (69.30%) | CPU usage: 0.00%
#
# ---------------------------- Extract get_jaffle_api ----------------------------
# Resources: 1/1 (100.0%) | Time: 0.02s | Rate: 66.54/s
# _dlt_pipeline_state: 1  | Time: 0.01s | Rate: 73.29/s
# Memory usage: 227.95 MB (69.30%) | CPU usage: 0.00%
#
# ---------------- Normalize get_jaffle_api in 1770066892.2430289 ----------------
# Files: 0/8 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 228.80 MB (69.30%) | CPU usage: 0.00%
#
# ---------------- Normalize get_jaffle_api in 1770066892.2430289 ----------------
# Files: 0/8 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Items: 0  | Time: 0.00s | Rate: 0.00/s
# Memory usage: 228.80 MB (69.30%) | CPU usage: 0.00%
#
# ---------------- Normalize get_jaffle_api in 1770066892.2430289 ----------------
# Files: 9/8 (112.5%) | Time: 5.40s | Rate: 1.67/s
# Items: 0  | Time: 5.40s | Rate: 0.00/s
# Memory usage: 253.59 MB (69.10%) | CPU usage: 0.00%
#
# ---------------- Normalize get_jaffle_api in 1770066892.2430289 ----------------
# Files: 9/8 (112.5%) | Time: 5.40s | Rate: 1.67/s
# Items: 244771  | Time: 5.40s | Rate: 45338.50/s
# Memory usage: 253.70 MB (69.10%) | CPU usage: 0.00%
#
# ------------------ Load get_jaffle_api in 1770066892.2430289 -------------------
# Jobs: 0/9 (0.0%) | Time: 0.00s | Rate: 0.00/s
# Memory usage: 253.83 MB (69.10%) | CPU usage: 0.00%
#
# ------------------ Load get_jaffle_api in 1770066892.2430289 -------------------
# Jobs: 10/13 (76.9%) | Time: 6.05s | Rate: 1.65/s
# Memory usage: 1402.02 MB (70.30%) | CPU usage: 0.00%
#
# ------------------ Load get_jaffle_api in 1770066892.2430289 -------------------
# Jobs: 13/13 (100.0%) | Time: 6.90s | Rate: 1.88/s
# Memory usage: 739.53 MB (69.50%) | CPU usage: 0.00%
#
# Pipeline jaffle_pipeline load step completed in 6.90 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset raw_data_20260202091452
# The duckdb destination used duckdb:////Users/macbook/Development/jaffle_poc/jaffle_pipeline.duckdb location to store data
# Load package 1770066892.2430289 is LOADED and contains no failed jobs

# %% [markdown]
# ### Observation of the results

# %%
# lets check our results

customers = pipeline.dataset().customers.df()
orders = pipeline.dataset().orders.df()
items= pipeline.dataset().items.df()
products = pipeline.dataset().products.df()
supplies = pipeline.dataset().supplies.df()
stores = pipeline.dataset().stores.df()

orders
# Out:
#                                          id  \
# 0      9bed808a-5074-4dfb-b1eb-388e2e60a6da
# 1      b83630c1-0fdc-4cd2-818d-0b6d4384ce86
# 2      3b4a03db-7b23-4673-a88a-7f51b01ca497
# 3      3368b213-6687-4338-bf73-b927ae72340f
# 4      739bf2f3-8d20-4159-9124-5451f1e4b136
# ...                                     ...
# 61943  d655d186-275f-4411-9a23-2f6d68f97578
# 61944  f6d1a004-6d02-4846-974c-aa48891cf1e1
# 61945  505da4ed-218d-47ce-bb62-caadac5da974
# 61946  1b41551c-b925-4cf5-820f-b014a23015a0
# 61947  2cf79940-d9ca-4d16-a1f2-d0d36ac929b1
#
#                                 customer_id  \
# 0      50a2d1c4-d788-4498-a6f7-dd75d4db588f
# 1      438005c2-dd1d-48aa-8bfd-7fb06851b5f8
# 2      5261268c-aa94-438a-921a-05efc0d414ac
# 3      f8486fce-bc07-4a4f-a6e9-ed6a06ba996c
# 4      341ed9b2-1760-4720-a1b1-42681d273c63
# ...                                     ...
# 61943  2d4e6ed6-f081-4049-b92a-7792dbe97b89
# 61944  3d6f18db-a49c-4563-9445-68d4e02bd664
# 61945  e8014144-a99b-4ca2-8418-56404aee2f08
# 61946  8f054a96-7920-42dc-b286-f6980ea8dbeb
# 61947  9f72b282-1f70-450b-988f-9b3029fa121e
#
#                                    store_id                ordered_at  \
# 0      4b6c2304-2b9e-41e4-942a-cf11a1819378 2016-09-01 15:01:00+00:00
# 1      4b6c2304-2b9e-41e4-942a-cf11a1819378 2016-09-01 10:39:00+00:00
# 2      4b6c2304-2b9e-41e4-942a-cf11a1819378 2016-09-01 07:46:00+00:00
# 3      4b6c2304-2b9e-41e4-942a-cf11a1819378 2016-09-01 14:39:00+00:00
# 4      4b6c2304-2b9e-41e4-942a-cf11a1819378 2016-09-01 10:57:00+00:00
# ...                                     ...                       ...
# 61943  40e6ddd6-b8f6-4e17-8bd6-5e53966809d2 2017-08-31 11:31:00+00:00
# 61944  40e6ddd6-b8f6-4e17-8bd6-5e53966809d2 2017-08-31 08:14:00+00:00
# 61945  40e6ddd6-b8f6-4e17-8bd6-5e53966809d2 2017-08-31 16:07:00+00:00
# 61946  40e6ddd6-b8f6-4e17-8bd6-5e53966809d2 2017-08-31 17:41:00+00:00
# 61947  40e6ddd6-b8f6-4e17-8bd6-5e53966809d2 2017-08-31 08:07:00+00:00
#
#        subtotal  tax_paid  order_total        _dlt_load_id         _dlt_id
# 0         700.0      42.0        742.0  1770064096.7823842  Waq/A3xnBBVLyw
# 1         700.0      42.0        742.0  1770064096.7823842  /lmSo0ytrHSgAQ
# 2         700.0      42.0        742.0  1770064096.7823842  9tuQxdwSunwYsg
# 3         600.0      36.0        636.0  1770064096.7823842  T2zcg9t/dt5gew
# 4        1100.0      65.0       1165.0  1770064096.7823842  odBi50uUXzfDyw
# ...         ...       ...          ...                 ...             ...
# 61943     600.0      24.0        624.0  1770064096.7823842  BR5BYB9jE9FaSQ
# 61944     600.0      24.0        624.0  1770064096.7823842  frCZBwVYrRRS+w
# 61945     600.0      24.0        624.0  1770064096.7823842  wFdHXFP9zpTF3A
# 61946    1200.0      48.0       1248.0  1770064096.7823842  z4aCwiVKt/iNzg
# 61947     600.0      24.0        624.0  1770064096.7823842  M50gIjcgyxhjjQ
#
# [61948 rows x 9 columns]

# %%
orders.describe()
# Out:
#            subtotal      tax_paid   order_total
# count  61948.000000  61948.000000  61948.000000
# mean    1028.998515     54.854668   1083.853183
# std     1089.309611     60.215220   1147.972882
# min        0.000000      0.000000      0.000000
# 25%      500.000000     24.000000    530.000000
# 50%      600.000000     36.000000    636.000000
# 75%     1100.000000     60.000000   1165.000000
# max     9900.000000    594.000000  10494.000000

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61948 entries, 0 to 61947
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            61948 non-null  str
#  1   customer_id   61948 non-null  str
#  2   store_id      61948 non-null  str
#  3   ordered_at    61948 non-null  datetime64[us, UTC]
#  4   subtotal      61948 non-null  float64
#  5   tax_paid      61948 non-null  float64
#  6   order_total   61948 non-null  float64
#  7   _dlt_load_id  61948 non-null  str
#  8   _dlt_id       61948 non-null  str
# dtypes: datetime64[us, UTC](1), float64(3), str(5)
# memory usage: 4.3 MB

# %%
# We can use it for a quick comparison on a ingested rows
row_counts = pipeline.dataset().get_row_counts.df()
row_counts
# Out:
#   table_name  row_count        _dlt_load_id         _dlt_id
# 0  customers        935  1770064096.7823842  qA0R33dxKZx1tg
# 1     orders      61948  1770064096.7823842  kXFJyzr68UfDmQ
# 2      items      90900  1770064096.7823842  RD5i6651vhfntg
# 3   products         10  1770064096.7823842  Y6/vE3njMCCvwA
# 4     stores          6  1770064096.7823842  tQdkctcfAlgSqw
# 5   supplies         65  1770064096.7823842  jW58/xfmtPVl9Q

# %% [markdown]
# ### Nex steps on the pipeline:
# - normalise data
# - check data types for all tables
# - move the orders endpoint to a cursor based incremetal loading based on `ordered_at`
# - use a deterministic has for  the primary keys that are string types into an `uuid` or `int` type
# - separate the concerns for a proper repo architecture:
#     sources into `jaffle_api_source.py` & pipeline into `jaffle_api_pipeline.py`
# - add a way to close the conection to duckdb in case of pipeline re-run
# - remove the dev_mode=True in the .pipeline()

# %% [markdown]
# ---

# %% [markdown]
# # 3. Taking the Pipeline to Production
#
# ## Phase 1: Infrastructure & Team Audit
#
# I perform this assessment before even writing a single line of production code.
# 1. Business Value & Strategy
#     Goal: Understand the ROI to justify the maintenance cost and ensure the pipeline is an asset, not a liability.
#     The "Why": Verify the actual business use case beyond simply "having the data."
#
#     Data Freshness & Lifecycle:
#
#     - SLAs: Is the data needed in real-time (streaming), hourly, or daily?
#     - Retention: Define a Hot/Cold storage strategy. How long must data be queryable before archiving?
#     - Disaster Recovery: Is there a backup/restore plan for the warehouse?
#
# 2. The team
#
# Who am I serving?
# - Target Audience: Identify the primary consumers (Data Analysts, Scientists, Stake holders).
# - Technical Proficiency: Are they SQL-native? How confortable in Python?
# - Tooling Familiarity: Do they prefer Snowflake, BigQuery, Looker, Streamlit...?
# - Partnership: Identify a Data referent in the business team who can validate data quality on the long run.
#
# 3. Governance & Compliance
# - PII Management: How do we obfuscate or hash sensitive data (GDPR compliance)?`
# - Data Residency: specific requirements for where data is stored (e.g., EU-only servers).
# - IAM & Security: Define role-based access control. Who can modify the pipeline vs. who can read the dataset?
#
# ## Phase 2: Technical Execution
#
# 1. Architecture & Design
#     - Diagramming: Create a high-level architecture diagram (e.g., using Excalidraw) to visualize flow and dependencies.
#     - Infrastructure Selection:
#     - Greenfield: For new setups, I recommend MotherDuck efficient & fast, easy deployment from Duckdb and EU server options.
#     - Other: Adapt to the client's existing stack (Snowflake/BigQuery).
#
# 2. Deployment & Orchestration
#
#     - Compute: decide where the python code runs.
#         - Simple: GitHub Actions with  cron jobs (Keep It Super Simple)
#         OR
#         - Scalable: Astro or Dagster (not a big fan of Cloud composer)
#     - Secrets Management: Never store keys in code. Use GitHub Secrets.
#     - CI/CD: Implement automated testing when deploying pipelines.
#
# 3. Source Reliability
#     - Implement unit test for data type checking and null-value. It could be also done in SQL via dbt unit tests
#     - API settings: Does the source support incremental loading (cursors/timestamps) or webhooks?
#     - Rate limiting: Implement backoff strategies to respect API quotas.
#
# 4. Documentation & Observability
#     - Lineage: Document the data transformation flow.
#     - Alerting: Set up notifications (Slack/email) for failures.
#     - Documentation access: Ensure documentation is updated automatically or easy to find the Source of truth.
